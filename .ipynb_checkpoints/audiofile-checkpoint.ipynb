# %%
import playsound
import speech_recognition as sr
import os 

root = "D:\Adria Tisnawati A\Matkul Polindra\Semester6\jurnal persiapan\Khusus Training\datasets"
path = os.path.join(root, "datasets")


for path, subdirs, files in os.walk(root):
    for name in files:
        print(os.path.join(path, name))
        

r = sr.Recognizer()

#datasets = sr.AudioFile('datasets.wav')
#with datasets as source:
#    audio = r.record(source)

r.recognize_google(audio, language='id-ID')

#try:
# attempt to read the file as WAV
#    self.audio_reader = wave.open(self.filename_or_fileobject, "rb")
#    self.little_endian = True  
# RIFF WAV is a little-endian format (most ``audioop`` operations assume that the frames are stored in little-endian form)
#except (wave.Error, EOFError):
#     self._i_opened_the_file = None
#        if isinstance(f, str):
#        f = builtins.open(f, 'rb')
#        self._i_opened_the_file = f
# Out:
# D:\Adria Tisnawati A\Matkul Polindra\Semester6\jurnal persiapan\Khusus Training\datasets\label klasifikasi kecurangan voice.txt
# D:\Adria Tisnawati A\Matkul Polindra\Semester6\jurnal persiapan\Khusus Training\datasets\1\1 001.wav
# D:\Adria Tisnawati A\Matkul Polindra\Semester6\jurnal persiapan\Khusus Training\datasets\1\1 0010.wav
# D:\Adria Tisnawati A\Matkul Polindra\Semester6\jurnal persiapan\Khusus Training\datasets\1\1 00100.wav
# D:\Adria Tisnawati A\Matkul Polindra\Semester6\jurnal persiapan\Khusus Training\datasets\1\1 0011.wav
# D:\Adria Tisnawati A\Matkul Polindra\Semester6\jurnal persiapan\Khusus Training\datasets\1\1 0012.wav
# D:\Adria Tisnawati A\Matkul Polindra\Semester6\jurnal persiapan\Khusus Training\datasets\1\1 0013.wav
# D:\Adria Tisnawati A\Matkul Polindra\Semester6\jurnal persiapan\Khusus Training\datasets\1\1 0014.wav
# D:\Adria Tisnawati A\Matkul Polindra\Semester6\jurnal persiapan\Khusus Training\datasets\1\1 0015.wav
# ...

# %%
import speech_recognition as sr

# obtain path to "english.wav" in the same folder as this script
from os import path
AUDIO_FILE = path.join(path.dirname(path.realpath(__file__)), "english.wav")
# AUDIO_FILE = path.join(path.dirname(path.realpath(__file__)), "french.aiff")
# AUDIO_FILE = path.join(path.dirname(path.realpath(__file__)), "chinese.flac")

# use the audio file as the audio source
r = sr.Recognizer()
with sr.AudioFile(AUDIO_FILE) as source:
    audio = r.record(source)  # read the entire audio file
    
    self._i_opened_the_file = None
    158         if isinstance(f, str):
--> 159             f = builtins.open(f, 'rb')
    160             self._i_opened_the_file = f
    161         # else, assume it is an open file object already
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15960/1789176550.py in <module>
#       3 # obtain path to "english.wav" in the same folder as this script
#       4 from os import path
# ----> 5 AUDIO_FILE = path.join(path.dirname(path.realpath(__file__)), "english.wav")
#       6 # AUDIO_FILE = path.join(path.dirname(path.realpath(__file__)), "french.aiff")
#       7 # AUDIO_FILE = path.join(path.dirname(path.realpath(__file__)), "chinese.flac")
#
# NameError: name '__file__' is not defined
